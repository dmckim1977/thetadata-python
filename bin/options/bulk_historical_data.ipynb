# %%
import os
import time

from thetadata import ThetaClient
from dotenv import load_dotenv

# Get environment variables in .env in project root
load_dotenv()

USERNAME=os.getenv('THETAUSER')
PASSWORD=os.getenv('THETAPASS')

client = ThetaClient(username=USERNAME, passwd=PASSWORD)

# %%
eod = client.bulk_historical_data_bulk_eod(
    start_date=20241202,
    end_date=20241206,
    exp=20241206,
    root="AAPL",
)
eod
# Out:
# ERROR:root:Requesting URL('http://127.0.0.1:25510/v2/bulk_hist/option/eod?start_date=20241202&end_date=20241206&exp=20241206&root=AAPL&use_csv=true')
#                                   root  strike right        ms_of_day  \
# trade_datetime
# 2024-12-02 17:23:37.542000-05:00  AAPL   100.0     C  17:23:37.542000
# 2024-12-03 17:17:32.694000-05:00  AAPL   100.0     C  17:17:32.694000
# 2024-12-04 17:19:39.652000-05:00  AAPL   100.0     C  17:19:39.652000
# 2024-12-05 17:22:21.696000-05:00  AAPL   100.0     C  17:22:21.696000
# 2024-12-06 17:22:31.813000-05:00  AAPL   100.0     C  17:22:31.813000
# ...                                ...     ...   ...              ...
# 2024-12-02 17:23:37.542000-05:00  AAPL   305.0     P  17:23:37.542000
# 2024-12-03 17:17:32.694000-05:00  AAPL   305.0     P  17:17:32.694000
# 2024-12-04 17:19:39.652000-05:00  AAPL   305.0     P  17:19:39.652000
# 2024-12-05 17:22:21.696000-05:00  AAPL   305.0     P  17:22:21.696000
# ...

# %%
quote = client.bulk_historical_data_bulk_quote(
    start_date=20231023,
    end_date=20241024,
    exp=20241025,
    root="AAPL",
    ivl=3_600_000,
    start_time="12:30",
    end_time="14:59",
)
quote
# Out:
#                            root  strike right ms_of_day  bid_size  \
# trade_datetime
# 2024-09-06 12:30:00-04:00  AAPL   100.0     C  12:30:00        39
# 2024-09-06 13:30:00-04:00  AAPL   100.0     C  13:30:00        52
# 2024-09-06 14:30:00-04:00  AAPL   100.0     C  14:30:00        63
# 2024-09-09 12:30:00-04:00  AAPL   100.0     C  12:30:00        66
# 2024-09-09 13:30:00-04:00  AAPL   100.0     C  13:30:00        52
# ...                         ...     ...   ...       ...       ...
# 2024-10-23 13:30:00-04:00  AAPL   300.0     P  13:30:00        61
# 2024-10-23 14:30:00-04:00  AAPL   300.0     P  14:30:00        55
# 2024-10-24 12:30:00-04:00  AAPL   300.0     P  12:30:00        30
# 2024-10-24 13:30:00-04:00  AAPL   300.0     P  13:30:00        53
# 2024-10-24 14:30:00-04:00  AAPL   300.0     P  14:30:00        57
#
#                            bid_exchange     bid  bid_condition  ask_size  \
# trade_datetime
# ...

# %%
ohlc = client.bulk_historical_data_bulk_ohlc(
    start_date=20231023,
    end_date=20241024,
    exp=20241025,
    root="AAPL",
    ivl=3_600_000,
    start_time="12:30",
    end_time="14:59",
)
ohlc
# Out:
#                            root  strike right ms_of_day  open  high  low  \
# trade_datetime
# 2024-09-20 12:30:00-04:00  AAPL   100.0     C  12:30:00   0.0   0.0  0.0
# 2024-09-20 13:30:00-04:00  AAPL   100.0     C  13:30:00   0.0   0.0  0.0
# 2024-10-04 12:30:00-04:00  AAPL   100.0     C  12:30:00   0.0   0.0  0.0
# 2024-10-04 13:30:00-04:00  AAPL   100.0     C  13:30:00   0.0   0.0  0.0
# 2024-09-20 12:30:00-04:00  AAPL   100.0     P  12:30:00   0.0   0.0  0.0
# ...                         ...     ...   ...       ...   ...   ...  ...
# 2024-09-30 13:30:00-04:00  AAPL   300.0     P  13:30:00   0.0   0.0  0.0
# 2024-10-01 12:30:00-04:00  AAPL   300.0     P  12:30:00   0.0   0.0  0.0
# 2024-10-01 13:30:00-04:00  AAPL   300.0     P  13:30:00   0.0   0.0  0.0
# 2024-10-10 12:30:00-04:00  AAPL   300.0     P  12:30:00   0.0   0.0  0.0
# 2024-10-10 13:30:00-04:00  AAPL   300.0     P  13:30:00   0.0   0.0  0.0
#
#                            close  volume  count       date
# trade_datetime
# ...

# %%
oi = client.bulk_historical_data_bulk_open_interest(
    start_date=20231023,
    end_date=20241024,
    exp=20241025,
    root="AAPL",
)
oi
# Out:
#                            root  strike right ms_of_day  open_interest  \
# trade_datetime
# 2024-09-09 06:30:16-04:00  AAPL   100.0     C  06:30:16              0
# 2024-09-10 06:30:05-04:00  AAPL   100.0     C  06:30:05              0
# 2024-09-11 06:30:14-04:00  AAPL   100.0     C  06:30:14              0
# 2024-09-12 06:30:20-04:00  AAPL   100.0     C  06:30:20              0
# 2024-09-13 06:30:15-04:00  AAPL   100.0     C  06:30:15              0
# ...                         ...     ...   ...       ...            ...
# 2024-10-18 06:30:05-04:00  AAPL   300.0     P  06:30:05              0
# 2024-10-21 06:30:01-04:00  AAPL   300.0     P  06:30:01              0
# 2024-10-22 06:30:14-04:00  AAPL   300.0     P  06:30:14              0
# 2024-10-23 06:30:24-04:00  AAPL   300.0     P  06:30:24              0
# 2024-10-24 06:30:12-04:00  AAPL   300.0     P  06:30:12              0
#
#                                 date
# trade_datetime
# 2024-09-09 06:30:16-04:00 2024-09-09
# ...

# %%
trade = client.bulk_historical_data_bulk_trade(
    start_date=20231023,
    end_date=20241024,
    exp=20241025,
    root="AAPL",
)
trade
# Out:
#                                   root  strike right        ms_of_day  \
# trade_datetime
# 2024-09-20 15:55:52.104000-04:00  AAPL   100.0     C  15:55:52.104000
# 2024-10-04 15:53:51.123000-04:00  AAPL   100.0     C  15:53:51.123000
# 2024-10-21 09:30:08.753000-04:00  AAPL   100.0     C  09:30:08.753000
# 2024-10-21 09:30:08.754000-04:00  AAPL   100.0     C  09:30:08.754000
# 2024-09-20 10:35:43.200000-04:00  AAPL   100.0     P  10:35:43.200000
# ...                                ...     ...   ...              ...
# 2024-10-01 15:54:47.802000-04:00  AAPL   300.0     P  15:54:47.802000
# 2024-10-01 15:54:47.870000-04:00  AAPL   300.0     P  15:54:47.870000
# 2024-10-03 09:44:16.411000-04:00  AAPL   300.0     P  09:44:16.411000
# 2024-10-03 09:48:57.265000-04:00  AAPL   300.0     P  09:48:57.265000
# 2024-10-10 15:54:40.072000-04:00  AAPL   300.0     P  15:54:40.072000
#
#                                     sequence  ext_condition1  ext_condition2  \
# trade_datetime
# ...

# %%
trade_quote = client.bulk_historical_data_bulk_trade_quote(
    start_date=20231023,
    end_date=20241024,
    exp=20241025,
    root="AAPL",
)
trade_quote
# Out:
#                                   root  strike right        ms_of_day  \
# trade_datetime
# 2024-09-20 15:55:52.104000-04:00  AAPL   100.0     C  15:55:52.104000
# 2024-10-04 15:53:51.123000-04:00  AAPL   100.0     C  15:53:51.123000
# 2024-10-21 09:30:08.753000-04:00  AAPL   100.0     C  09:30:08.753000
# 2024-10-21 09:30:08.754000-04:00  AAPL   100.0     C  09:30:08.754000
# 2024-09-20 10:35:43.200000-04:00  AAPL   100.0     P  10:35:43.200000
# ...                                ...     ...   ...              ...
# 2024-10-01 15:54:47.802000-04:00  AAPL   300.0     P  15:54:47.802000
# 2024-10-01 15:54:47.870000-04:00  AAPL   300.0     P  15:54:47.870000
# 2024-10-03 09:44:16.411000-04:00  AAPL   300.0     P  09:44:16.411000
# 2024-10-03 09:48:57.265000-04:00  AAPL   300.0     P  09:48:57.265000
# 2024-10-10 15:54:40.072000-04:00  AAPL   300.0     P  15:54:40.072000
#
#                                     sequence  ext_condition1  ext_condition2  \
# trade_datetime
# ...

# %%
eod_greeks = client.bulk_historical_data_bulk_eod_greeks(
        start_date=20241024,
        end_date=20241024,
        exp=20241024,
        root="SPXW",
    )
eod_greeks
# Out:
#                                   root  strike right        ms_of_day  \
# trade_datetime
# 2024-10-21 11:14:30.630000-04:00  SPXW  2400.0     C  11:14:30.630000
# 2024-10-22 00:00:00-04:00         SPXW  2400.0     C         00:00:00
# 2024-10-23 10:06:02.664000-04:00  SPXW  2400.0     C  10:06:02.664000
# 2024-10-24 03:16:03.511000-04:00  SPXW  2400.0     C  03:16:03.511000
# 2024-10-21 00:00:00-04:00         SPXW  2400.0     P         00:00:00
# ...                                ...     ...   ...              ...
# 2024-10-24 14:39:52.558000-04:00  SPXW  7600.0     C  14:39:52.558000
# 2024-10-21 11:14:30.630000-04:00  SPXW  7600.0     P  11:14:30.630000
# 2024-10-22 00:00:00-04:00         SPXW  7600.0     P         00:00:00
# 2024-10-23 00:00:00-04:00         SPXW  7600.0     P         00:00:00
# 2024-10-24 00:00:00-04:00         SPXW  7600.0     P         00:00:00
#
#                                      open     high      low    close  volume  \
# trade_datetime
# ...

# %%
all_greeks = client.bulk_historical_data_bulk_all_greeks(
        start_date=20241024,
        end_date=20241024,
        exp=20241024,
        root="SPXW",
        ivl=3_600_000,
    )
all_greeks
# Out:
#                            root  strike right ms_of_day     bid     ask  \
# trade_datetime
# 2024-10-24 10:30:00-04:00  SPXW  2400.0     C  10:30:00  3402.7  3413.6
# 2024-10-24 11:30:00-04:00  SPXW  2400.0     C  11:30:00  3399.8  3405.2
# 2024-10-24 12:30:00-04:00  SPXW  2400.0     C  12:30:00  3397.6  3399.1
# 2024-10-24 13:30:00-04:00  SPXW  2400.0     C  13:30:00  3408.3  3409.8
# 2024-10-24 14:30:00-04:00  SPXW  2400.0     C  14:30:00  3406.4  3407.9
# ...                         ...     ...   ...       ...     ...     ...
# 2024-10-24 11:30:00-04:00  SPXW  7600.0     P  11:30:00  1794.8  1800.2
# 2024-10-24 12:30:00-04:00  SPXW  7600.0     P  12:30:00  1800.9  1802.4
# 2024-10-24 13:30:00-04:00  SPXW  7600.0     P  13:30:00  1790.2  1791.7
# 2024-10-24 14:30:00-04:00  SPXW  7600.0     P  14:30:00  1792.1  1793.6
# 2024-10-24 15:30:00-04:00  SPXW  7600.0     P  15:30:00  1782.3  1792.0
#
#                             delta    theta    vega     rho  ...  ultima  \
# ...

# %%
client.kill()
client.status()
# Out:
# ERROR:root:TBD
# ERROR:root:Could not get mdds status. Error: [WinError 10061] No connection could be made because the target machine actively refused it
