# %%
import os
import time

import thetadata
from thetadata import ThetaClient
from dotenv import load_dotenv

# %%
# Get environment variables in .env in project root
load_dotenv()

USERNAME=os.getenv('THETAUSER')
PASSWORD=os.getenv('THETAPASS')

# %%
client = ThetaClient(username=USERNAME, passwd=PASSWORD)
time.sleep(8) # TODO because it isn't started yet. Need to fix
# Out:
# If you require API support, feel free to join our discord server! http://discord.thetadata.us
# [10-28-2024 12:29:39] INFO: Starting Theta Terminal v1.6.7 Revision A...
# [10-28-2024 12:29:39] INFO: Config dir: C:\Users\david\ThetaData\ThetaTerminal
# [10-28-2024 12:29:40] INFO: [MDDS] Attempting login as davidmckim@gmail.com
# [10-28-2024 12:29:40] INFO: [FPSS] Attempting login as davidmckim@gmail.com
# [10-28-2024 12:29:41] INFO: [MDDS] CONNECTED: [nj-a.thetadata.us:12000], Bundle: STOCK.FREE, OPTION.PRO, INDEX.FREE
# [10-28-2024 12:29:42] INFO: [FPSS] CONNECTED: [nj-a.thetadata.us:20000], Bundle: STOCK.FREE, OPTION.PRO, INDEX.FREE

# %%
client.status()

# %%
iv = client.historical_implied_volatility(
        start_date=20241021,
        end_date=20241024,
        exp=20241024,
        ivl=3_600_000,
        right='C',
        root="SPXW",
        strike=5850000
    )
iv
# Out:
# Handling page 1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 iv = client.historical_implied_volatility(
#       2         start_date=20241021,
#       3         end_date=20241024,
#       4         exp=20241024,
#       5         ivl=3_600_000,
#       6         right='C',
#       7         root="SPXW",
#       8         strike=5850000
#       9     )
#      10 iv
#
# File ~\Documents\github\forks\thetadata\parsing.py:120, in with_pagination.<locals>.wrapper(self, *args, **kwargs)
#     114 handler = DataHandler(
#     115     url=url,
#     116     parser=parse_trade
#     117 )
#     119 # Get paginated data
# --> 120 return handler.get_paginated_data(url, params)
#
# File ~\Documents\github\forks\thetadata\parsing.py:80, in DataHandler.get_paginated_data(self, url, params, timeout)
#      73 response = httpx.get(
#      74     url,
# ...

# %%
greeks = client.historical_greeks(
        start_date=20241021,
        end_date=20241024,
        exp=20241024,
        ivl=3_600_000,
        right='C',
        root="SPXW",
        strike=5850000
    )
greeks
# Out:
#                           ms_of_day    bid    ask   delta    theta      vega  \
# trade_datetime
# 2024-10-21 10:00:00-04:00  10:00:00  30.30  30.70  0.5813  -4.3657  207.5098
# 2024-10-21 11:00:00-04:00  11:00:00  22.80  23.00  0.4794  -4.4629  211.0900
# 2024-10-21 12:00:00-04:00  12:00:00  21.30  21.50  0.4646  -4.3598  210.4657
# 2024-10-21 13:00:00-04:00  13:00:00  22.70  22.90  0.4966  -4.2441  211.4635
# 2024-10-21 14:00:00-04:00  14:00:00  24.50  24.80  0.5274  -4.1931  211.1312
# 2024-10-21 15:00:00-04:00  15:00:00  20.00  20.20  0.4636  -4.1261  210.4244
# 2024-10-21 16:00:00-04:00  16:00:00  26.30  26.90  0.5503  -4.2157  210.0607
# 2024-10-21 17:00:00-04:00  17:00:00  27.00  27.90  0.5434  -4.4233  210.4701
# 2024-10-21 18:00:00-04:00  18:00:00  27.00  27.90  0.5434  -4.4233  210.4701
# 2024-10-21 19:00:00-04:00  19:00:00  27.00  27.90  0.5434  -4.4233  210.4701
# 2024-10-21 20:00:00-04:00  20:00:00  27.00  27.90  0.5434  -4.4233  210.4701
# ...

# %%
greeks_second_order = client.historical_greeks_second_order(
        start_date=20241021,
        end_date=20241024,
        exp=20241024,
        ivl=3_600_000,
        right='C',
        root="SPXW",
        strike=5850000
    )
greeks_second_order
# Out:
#                           ms_of_day    bid    ask   gamma   vanna     charm  \
# trade_datetime
# 2024-10-21 10:00:00-04:00  10:00:00  30.30  30.70  0.0064 -0.6725    2.8048
# 2024-10-21 11:00:00-04:00  11:00:00  22.80  23.00  0.0064  0.2128   -3.3271
# 2024-10-21 12:00:00-04:00  12:00:00  21.30  21.50  0.0065  0.3444   -4.2430
# 2024-10-21 13:00:00-04:00  13:00:00  22.70  22.90  0.0068  0.0664   -2.3780
# 2024-10-21 14:00:00-04:00  14:00:00  24.50  24.80  0.0069 -0.2180   -0.5369
# 2024-10-21 15:00:00-04:00  15:00:00  20.00  20.20  0.0069  0.3728   -4.4035
# 2024-10-21 16:00:00-04:00  16:00:00  26.30  26.90  0.0068 -0.4266    0.8706
# 2024-10-21 17:00:00-04:00  17:00:00  27.00  27.90  0.0065 -0.3428    0.5365
# 2024-10-21 18:00:00-04:00  18:00:00  27.00  27.90  0.0065 -0.3428    0.5365
# 2024-10-21 19:00:00-04:00  19:00:00  27.00  27.90  0.0065 -0.3428    0.5365
# 2024-10-21 20:00:00-04:00  20:00:00  27.00  27.90  0.0065 -0.3428    0.5365
# ...

# %%
greeks_third_order = client.historical_greeks_third_order(
        start_date=20241021,
        end_date=20241024,
        exp=20241024,
        ivl=3_600_000,
        right='C',
        root="SPXW",
        strike=5850000
    )
greeks_third_order
# Out:
#                           ms_of_day    bid    ask  speed  zomma   color  \
# trade_datetime
# 2024-10-21 10:00:00-04:00  10:00:00  30.30  30.70    0.0    0.0 -0.0967
# 2024-10-21 11:00:00-04:00  11:00:00  22.80  23.00    0.0    0.0 -0.1010
# 2024-10-21 12:00:00-04:00  12:00:00  21.30  21.50    0.0    0.0 -0.0988
# 2024-10-21 13:00:00-04:00  13:00:00  22.70  22.90    0.0    0.0 -0.0953
# 2024-10-21 14:00:00-04:00  14:00:00  24.50  24.80    0.0    0.0 -0.0934
# 2024-10-21 15:00:00-04:00  15:00:00  20.00  20.20    0.0    0.0 -0.0930
# 2024-10-21 16:00:00-04:00  16:00:00  26.30  26.90    0.0    0.0 -0.0936
# 2024-10-21 17:00:00-04:00  17:00:00  27.00  27.90    0.0    0.0 -0.0988
# 2024-10-21 18:00:00-04:00  18:00:00  27.00  27.90    0.0    0.0 -0.0988
# 2024-10-21 19:00:00-04:00  19:00:00  27.00  27.90    0.0    0.0 -0.0988
# 2024-10-21 20:00:00-04:00  20:00:00  27.00  27.90    0.0    0.0 -0.0988
# 2024-10-21 21:00:00-04:00  21:00:00  21.90  22.40    0.0    0.0 -0.0767
# ...

# %%
all_greeks = client.historical_all_greeks(
        start_date=20241021,
        end_date=20241024,
        exp=20241024,
        ivl=3_600_000,
        right='C',
        root="SPXW",
        strike=5850000
    )
all_greeks
# Out:
#                           ms_of_day    bid    ask   delta    theta      vega  \
# trade_datetime
# 2024-10-21 10:00:00-04:00  10:00:00  30.30  30.70  0.5813  -4.3657  207.5098
# 2024-10-21 11:00:00-04:00  11:00:00  22.80  23.00  0.4794  -4.4629  211.0900
# 2024-10-21 12:00:00-04:00  12:00:00  21.30  21.50  0.4646  -4.3598  210.4657
# 2024-10-21 13:00:00-04:00  13:00:00  22.70  22.90  0.4966  -4.2441  211.4635
# 2024-10-21 14:00:00-04:00  14:00:00  24.50  24.80  0.5274  -4.1931  211.1312
# 2024-10-21 15:00:00-04:00  15:00:00  20.00  20.20  0.4636  -4.1261  210.4244
# 2024-10-21 16:00:00-04:00  16:00:00  26.30  26.90  0.5503  -4.2157  210.0607
# 2024-10-21 17:00:00-04:00  17:00:00  27.00  27.90  0.5434  -4.4233  210.4701
# 2024-10-21 18:00:00-04:00  18:00:00  27.00  27.90  0.5434  -4.4233  210.4701
# 2024-10-21 19:00:00-04:00  19:00:00  27.00  27.90  0.5434  -4.4233  210.4701
# 2024-10-21 20:00:00-04:00  20:00:00  27.00  27.90  0.5434  -4.4233  210.4701
# ...

# %%
trade_greeks = client.historical_trade_greeks(
        start_date=20241010,
        end_date=20241024,
        exp=20241024,
        ivl=3_600_000,
        # ivl=1000,
        right='C',
        root="SPXW",
        perf_boost=True,
        strike=5850000
    )
trade_greeks
# Out:
# Handling page 1
# ...

# %%
trade_greeks_second_order = client.historical_trade_greeks_second_order(
        start_date=20241021,
        end_date=20241024,
        exp=20241024,
        ivl=3_600_000,
        right='C',
        root="SPXW",
        perf_boost=True,
        strike=5850000
    )
trade_greeks_second_order
# Out:
#                                         ms_of_day    sequence  ext_condition1  \
# trade_datetime
# 2024-10-21 09:30:30.943000-04:00  09:30:30.943000  -638715380             255
# 2024-10-21 09:32:36.350000-04:00  09:32:36.350000  -622435508             255
# 2024-10-21 09:38:54.917000-04:00  09:38:54.917000  -580618563             255
# 2024-10-21 09:51:02.726000-04:00  09:51:02.726000  -514471125             255
# 2024-10-21 09:55:43.921000-04:00  09:55:43.921000  -493279889             255
# ...                                           ...         ...             ...
# 2024-10-24 15:57:05.415000-04:00  15:57:05.415000 -2126770318             255
# 2024-10-24 15:57:49.122000-04:00  15:57:49.122000 -2122498806             255
# 2024-10-24 15:57:51.626000-04:00  15:57:51.626000 -2122247169             255
# 2024-10-24 15:57:55.621000-04:00  15:57:55.621000 -2121931986             255
# 2024-10-24 15:59:52.099000-04:00  15:59:52.099000 -2106271375             255
#
# ...

# %%
trade_greeks_third_order = client.historical_trade_greeks_third_order(
        start_date=20241021,
        end_date=20241024,
        exp=20241024,
        ivl=3_600_000,
        right='C',
        root="SPXW",
        perf_boost=True,
        strike=5850000
    )
trade_greeks_third_order
# Out:
#                                         ms_of_day    sequence  ext_condition1  \
# trade_datetime
# 2024-10-21 09:30:30.943000-04:00  09:30:30.943000  -638715380             255
# 2024-10-21 09:32:36.350000-04:00  09:32:36.350000  -622435508             255
# 2024-10-21 09:38:54.917000-04:00  09:38:54.917000  -580618563             255
# 2024-10-21 09:51:02.726000-04:00  09:51:02.726000  -514471125             255
# 2024-10-21 09:55:43.921000-04:00  09:55:43.921000  -493279889             255
# ...                                           ...         ...             ...
# 2024-10-24 15:57:05.415000-04:00  15:57:05.415000 -2126770318             255
# 2024-10-24 15:57:49.122000-04:00  15:57:49.122000 -2122498806             255
# 2024-10-24 15:57:51.626000-04:00  15:57:51.626000 -2122247169             255
# 2024-10-24 15:57:55.621000-04:00  15:57:55.621000 -2121931986             255
# 2024-10-24 15:59:52.099000-04:00  15:59:52.099000 -2106271375             255
#
# ...

# %%
client.kill()
client.status()
# Out:
# ERROR:root:TBD
# ERROR:root:Could not get mdds status. Error: [WinError 10061] No connection could be made because the target machine actively refused it
